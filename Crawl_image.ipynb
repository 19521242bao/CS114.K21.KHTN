# %%
# !ls
# Out:
# drive  sample_data

# %%
cd ./drive/My Drive/google-images-download
# Out:
# /content/drive

# %%
# !pip install -U -r requirements.txt
# Out:
#   File "<ipython-input-8-a598ca7e53ef>", line 1
#     python bing_scraper.py --search "lavie" --limit 1000 --size "large" --download --chromedriver "D:\chromedriver.exe"
#                       ^
# SyntaxError: invalid syntax

# %%
# !python bing_scraper.py --search "lavie" --limit 1000 --size "large" --download --chromedriver "D:\chromedriver.exe"
